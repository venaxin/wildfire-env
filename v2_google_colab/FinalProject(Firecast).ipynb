# %%
# --- CELL 1: SETUP ---
# 1. Install Reinforcement Learning dependencies
# !pip install gymnasium stable-baselines3 shimmy pygame

# 2. Unzip the environment file (Assumes you uploaded 'wildfire-env.zip')
# The -o flag overwrites files without asking (good for re-running)
# !unzip -o wildfire-env.zip
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.6.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 7.3 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy, stable-baselines3
# Successfully installed shimmy-2.0.0 stable-baselines3-2.7.0
# Archive:  wildfire-env.zip
#    creating: wildfire-env/
#   inflating: wildfire-env/evaluate_v0.ipynb
#   inflating: wildfire-env/train_v0.ipynb
#   inflating: wildfire-env/.DS_Store
#   inflating: __MACOSX/wildfire-env/._.DS_Store
#   inflating: wildfire-env/LICENSE
#   inflating: wildfire-env/ppo_fire_squad_coop_v0.zip
#   inflating: wildfire-env/train_greedy_v0.ipynb
#    creating: wildfire-env/dist/
#   inflating: wildfire-env/train_greedy.ipynb
#   inflating: wildfire-env/pyproject.toml
#   inflating: wildfire-env/evaluate.ipynb
#    creating: wildfire-env/docs/
#   inflating: wildfire-env/README.md
#   inflating: wildfire-env/firecast.ipynb
#   inflating: wildfire-env/.gitignore
#    creating: wildfire-env/firecastrl_env/
#    creating: wildfire-env/.ipynb_checkpoints/
#   inflating: wildfire-env/train.ipynb
#    creating: wildfire-env/.git/
#   inflating: wildfire-env/dist/firecastrl_env-0.1.2-py3-none-any.whl
#   inflating: wildfire-env/dist/firecastrl_env-0.1.2.tar.gz
#   inflating: wildfire-env/docs/screenshot_early.png
#   inflating: wildfire-env/docs/screenshot_active.png
#    creating: wildfire-env/firecastrl_env/wrappers/
#   inflating: wildfire-env/firecastrl_env/.DS_Store
#   inflating: __MACOSX/wildfire-env/firecastrl_env/._.DS_Store
#   inflating: wildfire-env/firecastrl_env/.pre-commit-config.yaml
#   inflating: wildfire-env/firecastrl_env/__init__.py
#    creating: wildfire-env/firecastrl_env/__pycache__/
#   inflating: wildfire-env/firecastrl_env/.gitignore
#    creating: wildfire-env/firecastrl_env/envs/
#   inflating: wildfire-env/.ipynb_checkpoints/train_greedy-checkpoint.ipynb
#   inflating: wildfire-env/.ipynb_checkpoints/train-checkpoint.ipynb
#   inflating: wildfire-env/.ipynb_checkpoints/firecast-checkpoint.ipynb
#   inflating: wildfire-env/.ipynb_checkpoints/evaluate-checkpoint.ipynb
#   inflating: wildfire-env/.ipynb_checkpoints/train_v0-checkpoint.ipynb
#   inflating: wildfire-env/.ipynb_checkpoints/README-checkpoint.md
#   inflating: wildfire-env/.ipynb_checkpoints/evaluate_v0-checkpoint.ipynb
#   inflating: wildfire-env/.ipynb_checkpoints/train_greedy_v0-checkpoint.ipynb
#   inflating: wildfire-env/.git/config
#    creating: wildfire-env/.git/objects/
#   inflating: wildfire-env/.git/HEAD
#    creating: wildfire-env/.git/info/
#    creating: wildfire-env/.git/logs/
#   inflating: wildfire-env/.git/description
#    creating: wildfire-env/.git/hooks/
#    creating: wildfire-env/.git/refs/
#   inflating: wildfire-env/.git/index
#    creating: wildfire-env/.git/branches/
#   inflating: wildfire-env/.git/packed-refs
#   inflating: wildfire-env/.git/COMMIT_EDITMSG
#   inflating: wildfire-env/.git/FETCH_HEAD
#   inflating: wildfire-env/firecastrl_env/wrappers/custom_reward.py
#   inflating: wildfire-env/firecastrl_env/wrappers/__init__.py
#    creating: wildfire-env/firecastrl_env/wrappers/__pycache__/
#   inflating: wildfire-env/firecastrl_env/wrappers/full_cells_observation.py
#   inflating: wildfire-env/firecastrl_env/wrappers/clip_reward.py
#   inflating: wildfire-env/firecastrl_env/__pycache__/__init__.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/wildfire_env.py
#   inflating: wildfire-env/firecastrl_env/envs/.DS_Store
#   inflating: __MACOSX/wildfire-env/firecastrl_env/envs/._.DS_Store
#   inflating: wildfire-env/firecastrl_env/envs/config.py
#   inflating: wildfire-env/firecastrl_env/envs/__init__.py
#    creating: wildfire-env/firecastrl_env/envs/__pycache__/
#    creating: wildfire-env/firecastrl_env/envs/fire_engine/
#    creating: wildfire-env/firecastrl_env/envs/environment/
#    creating: wildfire-env/firecastrl_env/envs/.ipynb_checkpoints/
#    creating: wildfire-env/firecastrl_env/envs/training_environments/
#    creating: wildfire-env/.git/objects/d0/
#    creating: wildfire-env/.git/objects/pack/
#    creating: wildfire-env/.git/objects/info/
#    creating: wildfire-env/.git/objects/99/
#    creating: wildfire-env/.git/objects/ff/
#    creating: wildfire-env/.git/objects/14/
#   inflating: wildfire-env/.git/info/exclude
#   inflating: wildfire-env/.git/logs/HEAD
#    creating: wildfire-env/.git/logs/refs/
#   inflating: wildfire-env/.git/hooks/commit-msg.sample
#   inflating: wildfire-env/.git/hooks/pre-rebase.sample
#   inflating: wildfire-env/.git/hooks/sendemail-validate.sample
#   inflating: wildfire-env/.git/hooks/pre-commit.sample
#   inflating: wildfire-env/.git/hooks/applypatch-msg.sample
#   inflating: wildfire-env/.git/hooks/fsmonitor-watchman.sample
#   inflating: wildfire-env/.git/hooks/pre-receive.sample
#   inflating: wildfire-env/.git/hooks/prepare-commit-msg.sample
#   inflating: wildfire-env/.git/hooks/post-update.sample
#   inflating: wildfire-env/.git/hooks/pre-merge-commit.sample
#   inflating: wildfire-env/.git/hooks/pre-applypatch.sample
#   inflating: wildfire-env/.git/hooks/pre-push.sample
#   inflating: wildfire-env/.git/hooks/update.sample
#   inflating: wildfire-env/.git/hooks/push-to-checkout.sample
#    creating: wildfire-env/.git/refs/heads/
#    creating: wildfire-env/.git/refs/tags/
#    creating: wildfire-env/.git/refs/remotes/
#   inflating: wildfire-env/firecastrl_env/wrappers/__pycache__/full_cells_observation.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/wrappers/__pycache__/clip_reward.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/wrappers/__pycache__/custom_reward.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/wrappers/__pycache__/__init__.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/__pycache__/config.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/__pycache__/wildfire_env.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/__pycache__/__init__.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/fire_engine/fire_engine.py
#    creating: wildfire-env/firecastrl_env/envs/fire_engine/__pycache__/
#   inflating: wildfire-env/firecastrl_env/envs/fire_engine/fire_spread_rate.py
#   inflating: wildfire-env/firecastrl_env/envs/fire_engine/utils.py
#   inflating: wildfire-env/firecastrl_env/envs/environment/enums.py
#   inflating: wildfire-env/firecastrl_env/envs/environment/vector.py
#   inflating: wildfire-env/firecastrl_env/envs/environment/cell.py
#   inflating: wildfire-env/firecastrl_env/envs/environment/wind.py
#    creating: wildfire-env/firecastrl_env/envs/environment/__pycache__/
#   inflating: wildfire-env/firecastrl_env/envs/environment/zone.py
#   inflating: wildfire-env/firecastrl_env/envs/environment/helper.py
#   inflating: wildfire-env/firecastrl_env/envs/.ipynb_checkpoints/wildfire_env-checkpoint.py
#   inflating: wildfire-env/firecastrl_env/envs/training_environments/landcover_1.png
#   inflating: wildfire-env/firecastrl_env/envs/training_environments/heightmap_1.png
#   inflating: wildfire-env/.git/objects/d0/7f3a93370937e89e7bab2f94ba01092ce27f0e
#   inflating: wildfire-env/.git/objects/pack/pack-abf096697bd01a0342e66cfc9d730bc2ce179595.idx
#   inflating: wildfire-env/.git/objects/pack/pack-abf096697bd01a0342e66cfc9d730bc2ce179595.rev
#   inflating: wildfire-env/.git/objects/pack/pack-abf096697bd01a0342e66cfc9d730bc2ce179595.pack
#   inflating: wildfire-env/.git/objects/99/5a256e874c16a464f3893a91defd7e6fec5dc1
#   inflating: wildfire-env/.git/objects/99/125f8e4d948ba206b79c8b4d3eef515ff045ee
#   inflating: wildfire-env/.git/objects/ff/5e48b745c5b7ec7eb6a9c98290392573c9b1b1
#   inflating: wildfire-env/.git/objects/14/16efa9cd05b1671af00a52cb0e78f8d719c53e
#    creating: wildfire-env/.git/logs/refs/heads/
#    creating: wildfire-env/.git/logs/refs/remotes/
#   inflating: wildfire-env/.git/refs/heads/main
#    creating: wildfire-env/.git/refs/remotes/origin/
#    creating: wildfire-env/.git/refs/remotes/upstream/
#   inflating: wildfire-env/firecastrl_env/envs/fire_engine/__pycache__/fire_engine.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/fire_engine/__pycache__/fire_spread_rate.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/fire_engine/__pycache__/utils.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/environment/__pycache__/vector.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/environment/__pycache__/enums.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/environment/__pycache__/cell.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/environment/__pycache__/wind.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/environment/__pycache__/helper.cpython-310.pyc
#   inflating: wildfire-env/firecastrl_env/envs/environment/__pycache__/zone.cpython-310.pyc
#   inflating: wildfire-env/.git/logs/refs/heads/main
#    creating: wildfire-env/.git/logs/refs/remotes/origin/
#    creating: wildfire-env/.git/logs/refs/remotes/upstream/
#   inflating: wildfire-env/.git/refs/remotes/origin/HEAD
#   inflating: wildfire-env/.git/refs/remotes/origin/main
#   inflating: wildfire-env/.git/refs/remotes/upstream/HEAD
#   inflating: wildfire-env/.git/refs/remotes/upstream/main
#   inflating: wildfire-env/.git/logs/refs/remotes/origin/HEAD
#   inflating: wildfire-env/.git/logs/refs/remotes/origin/main
#   inflating: wildfire-env/.git/logs/refs/remotes/upstream/HEAD
#   inflating: wildfire-env/.git/logs/refs/remotes/upstream/main

# %%
# --- CELL 2: MOUNT DRIVE & FIX PATHS ---
import sys
import os
import shutil
from google.colab import drive

# 1. Mount Google Drive (So models save while you sleep)
drive.mount('/content/drive')
drive_save_path = "/content/drive/MyDrive/FirecastRL_Models"
os.makedirs(drive_save_path, exist_ok=True)
print(f"✅ Google Drive Mounted. Models will save to: {drive_save_path}")

# 2. Fix the Folder Name Issue
# Python packages cannot have hyphens (-), only underscores (_)
# We check if 'wildfire-env' exists and rename/restructure it so imports work
if os.path.exists("wildfire-env"):
    # Check if this is the package itself or a parent folder
    if os.path.exists("wildfire-env/firecastrl_env"):
        # It's a parent folder, add it to path
        sys.path.append(os.path.abspath("wildfire-env"))
        print("✅ Added 'wildfire-env' folder to Python path.")
    else:
        # It might be the package named wrongly. Let's rename it.
        if os.path.exists("firecastrl_env"):
            shutil.rmtree("firecastrl_env") # Remove existing to avoid conflict
        os.rename("wildfire-env", "firecastrl_env")
        sys.path.append(os.path.abspath("."))
        print("✅ Renamed 'wildfire-env' to 'firecastrl_env' for correct importing.")

# 3. Verify Import
try:
    from firecastrl_env.envs.wildfire_env import WildfireEnv
    print("✅ SUCCESS: Environment imported correctly!")
except ImportError as e:
    print(f"❌ CRITICAL ERROR: {e}")
    print("Please verify the contents of your zip file.")
# Out:
# Mounted at /content/drive
# ✅ Google Drive Mounted. Models will save to: /content/drive/MyDrive/FirecastRL_Models
# ✅ Added 'wildfire-env' folder to Python path.
# ✅ SUCCESS: Environment imported correctly!

# %%
# --- CELL 3: DEFINE WRAPPERS ---
import gymnasium as gym
import numpy as np
from firecastrl_env.envs.environment import helper
# Import Enum to be safe about the burning value
from firecastrl_env.envs.environment.enums import FireState

# 1. Safety Wrapper (Fixes Infinity Bug)
class SafeWildfireWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
    def observation(self, obs):
        if 'cells' in obs:
            obs['cells'] = np.nan_to_num(obs['cells'], posinf=-1.0)
        return obs

# 2. Multi-Agent Reward Wrapper (Coop vs Comp)
class MultiAgentRewardWrapper(gym.Wrapper):
    def __init__(self, env, mode="cooperative"):
        super().__init__(env)
        self.mode = mode.lower()
        if self.mode not in ["cooperative", "competitive"]:
            raise ValueError("Mode must be 'cooperative' or 'competitive'")

    def step(self, action):
        # Run the environment step normally
        obs, original_reward, terminated, truncated, info = self.env.step(action)

        # Override the reward based on the selected mode
        if self.mode == "cooperative":
            new_reward = self._calculate_cooperative(info, obs)
        else:
            new_reward = self._calculate_competitive(info)

        return obs, float(new_reward), terminated, truncated, info

    def _calculate_cooperative(self, info, obs):
        """Global Goal: Save the forest (Punish burning cells)."""
        curr_burning = info['cells_burning']
        total_extinguished = obs['quenched_cells'][0]

        reward = 0.0
        reward += 10.0 * total_extinguished
        reward -= 0.1 * curr_burning  # TEAM PENALTY
        reward -= self._calculate_wasted_water_penalty()

        return np.clip(reward, -50.0, 50.0)

    def _calculate_competitive(self, info):
        """Greedy Goal: Just get points (No penalty for burning forest)."""
        wasted_penalty = self._calculate_wasted_water_penalty()
        total_extinguished = self.env.unwrapped.state['quenched_cells'][0]

        reward = 0.0
        reward += 10.0 * total_extinguished
        reward -= wasted_penalty
        # CRITICAL: No penalty for 'curr_burning'

        return np.clip(reward, -50.0, 50.0)

    def _calculate_wasted_water_penalty(self):
        """Check if anyone dropped water on nothing."""
        penalty = 0.0
        base_env = self.env.unwrapped

        for i in range(base_env.num_agents):
            last_act = base_env.state['last_action'][i]
            hx, hy = base_env.state['helicopter_coord'][i]

            if last_act == 4: # Attempted Drop
                cell_idx = helper.get_grid_index_for_location(hx, hy, base_env.gridWidth)
                cell = base_env.cells[cell_idx]

                # Use the imported Enum for safety
                if cell.fireState != FireState.Burning:
                    penalty += 2.0

        return penalty

# %%
# --- CELL 4: TRAIN EXPERIMENT A (COOPERATIVE) ---
from stable_baselines3 import PPO
from firecastrl_env.envs.wildfire_env import WildfireEnv

print("🔥 STARTED: Experiment A (Cooperative)")

# 1. Setup
raw_env = WildfireEnv(num_agents=3, render_mode=None)
safe_env = SafeWildfireWrapper(raw_env)
coop_env = MultiAgentRewardWrapper(safe_env, mode="cooperative")

# 2. Train
model_coop = PPO("MultiInputPolicy", coop_env, verbose=1)
model_coop.learn(total_timesteps=100_000)

# 3. Save to Google Drive
save_name = f"{drive_save_path}/ppo_fire_squad_coop"
model_coop.save(save_name)
print(f"✅ FINISHED A: Cooperative model saved to {save_name}.zip")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# 🔥 STARTED: Experiment A (Cooperative)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 614       |
# |    ep_rew_mean     | -3.55e+03 |
# | time/              |           |
# |    fps             | 33        |
# |    iterations      | 1         |
# |    time_elapsed    | 61        |
# |    total_timesteps | 2048      |
# ----------------------------------
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 609         |
# |    ep_rew_mean          | -3.5e+03    |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 2           |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009614508 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | -0.00368    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.94e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 9.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 547         |
# |    ep_rew_mean          | -3.14e+03   |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 3           |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008052262 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.000655    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.34e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 1.04e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 561          |
# |    ep_rew_mean          | -3.14e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 4            |
# |    time_elapsed         | 255          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0071010445 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0.000408     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.47e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 8.82e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 558        |
# |    ep_rew_mean          | -3.09e+03  |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 5          |
# |    time_elapsed         | 320        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01051195 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.78      |
# |    explained_variance   | 0.000107   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.26e+03   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00866   |
# |    value_loss           | 7.54e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 560         |
# |    ep_rew_mean          | -3.08e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 6           |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009805825 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 0.000169    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.3e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 8.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 546         |
# |    ep_rew_mean          | -2.98e+03   |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 7           |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007132964 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 6.52e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.53e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00967    |
# |    value_loss           | 8.56e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 544        |
# |    ep_rew_mean          | -2.99e+03  |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 8          |
# |    time_elapsed         | 513        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00808548 |
# |    clip_fraction        | 0.0811     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.76      |
# |    explained_variance   | 6.18e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.22e+03   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 6.71e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 531         |
# |    ep_rew_mean          | -2.93e+03   |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 9           |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008440962 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 5.2e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1e+03     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 9.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 534         |
# |    ep_rew_mean          | -2.94e+03   |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 10          |
# |    time_elapsed         | 642         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009547245 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 4.74e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.32e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 9e+03       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 533          |
# |    ep_rew_mean          | -2.94e+03    |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 11           |
# |    time_elapsed         | 707          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0068736877 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.7         |
# |    explained_variance   | 2.87e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00719     |
# |    value_loss           | 6.68e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 543         |
# |    ep_rew_mean          | -2.98e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 12          |
# |    time_elapsed         | 765         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008660706 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 2.94e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.95e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00942    |
# |    value_loss           | 7.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | -3.02e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 13          |
# |    time_elapsed         | 829         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007810207 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 1.25e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4e+03     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 6.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | -3.04e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 14          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008368491 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 1.99e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7e+03     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0076     |
# |    value_loss           | 6.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 566         |
# |    ep_rew_mean          | -3.08e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 15          |
# |    time_elapsed         | 948         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009301501 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 1.35e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.1e+03     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 6.63e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 571          |
# |    ep_rew_mean          | -3.1e+03     |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 16           |
# |    time_elapsed         | 1009         |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0063403756 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.64        |
# |    explained_variance   | 1.26e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 6.23e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 567        |
# |    ep_rew_mean          | -3.07e+03  |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 17         |
# |    time_elapsed         | 1072       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00731006 |
# |    clip_fraction        | 0.0525     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.62      |
# |    explained_variance   | 1.25e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.96e+03   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00736   |
# |    value_loss           | 6.42e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 564          |
# |    ep_rew_mean          | -3.04e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 18           |
# |    time_elapsed         | 1135         |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0084315855 |
# |    clip_fraction        | 0.0715       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.59        |
# |    explained_variance   | 1.13e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.67e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00675     |
# |    value_loss           | 5.9e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 571         |
# |    ep_rew_mean          | -3.05e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 19          |
# |    time_elapsed         | 1197        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004331842 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 9.42e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 5.51e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 567          |
# |    ep_rew_mean          | -3.01e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 20           |
# |    time_elapsed         | 1260         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0064338436 |
# |    clip_fraction        | 0.0719       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 1.86e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.99e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 4e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 568          |
# |    ep_rew_mean          | -3.02e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 21           |
# |    time_elapsed         | 1320         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0069129355 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.57        |
# |    explained_variance   | 6.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 5.24e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 567          |
# |    ep_rew_mean          | -3e+03       |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 22           |
# |    time_elapsed         | 1383         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0091026295 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.54        |
# |    explained_variance   | 7.45e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8e+03      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 6.16e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | -2.97e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 23          |
# |    time_elapsed         | 1446        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010928968 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 5.6e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 5.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 560         |
# |    ep_rew_mean          | -2.93e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 24          |
# |    time_elapsed         | 1510        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009964934 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 4.89e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 4.59e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 563         |
# |    ep_rew_mean          | -2.95e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 25          |
# |    time_elapsed         | 1569        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008451695 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.48       |
# |    explained_variance   | 4.05e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+03     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00967    |
# |    value_loss           | 4.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 566         |
# |    ep_rew_mean          | -2.94e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 26          |
# |    time_elapsed         | 1632        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010112021 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.47       |
# |    explained_variance   | 5.9e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00854    |
# |    value_loss           | 4.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 561         |
# |    ep_rew_mean          | -2.91e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 27          |
# |    time_elapsed         | 1695        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009095519 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 2.62e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 3.56e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 560          |
# |    ep_rew_mean          | -2.87e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 28           |
# |    time_elapsed         | 1759         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0077334326 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.43        |
# |    explained_variance   | 4.59e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.6e+03      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00598     |
# |    value_loss           | 5.05e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | -2.85e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 29          |
# |    time_elapsed         | 1820        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008430129 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 3.64e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 3.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 554         |
# |    ep_rew_mean          | -2.8e+03    |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 30          |
# |    time_elapsed         | 1885        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008401603 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 3.1e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00668    |
# |    value_loss           | 4.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 555         |
# |    ep_rew_mean          | -2.81e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 31          |
# |    time_elapsed         | 1955        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008796875 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00626    |
# |    value_loss           | 4.17e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 554         |
# |    ep_rew_mean          | -2.79e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 32          |
# |    time_elapsed         | 2016        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010098606 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.34       |
# |    explained_variance   | 3.76e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 5.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 561         |
# |    ep_rew_mean          | -2.82e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 33          |
# |    time_elapsed         | 2075        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008630227 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 3.04e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2e+03       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00592    |
# |    value_loss           | 4.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | -2.83e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 34          |
# |    time_elapsed         | 2135        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008511785 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 2.98e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00671    |
# |    value_loss           | 4.19e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 566          |
# |    ep_rew_mean          | -2.85e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 35           |
# |    time_elapsed         | 2198         |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0067279856 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.38        |
# |    explained_variance   | 3.64e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00357     |
# |    value_loss           | 4.17e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 569         |
# |    ep_rew_mean          | -2.85e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 36          |
# |    time_elapsed         | 2261        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008556892 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.37       |
# |    explained_variance   | 4.77e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00503    |
# |    value_loss           | 5.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 569         |
# |    ep_rew_mean          | -2.83e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 37          |
# |    time_elapsed         | 2324        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012190949 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 7.45e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 4.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 572         |
# |    ep_rew_mean          | -2.84e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 38          |
# |    time_elapsed         | 2384        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008034908 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.0215      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 3.82e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 571          |
# |    ep_rew_mean          | -2.82e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 39           |
# |    time_elapsed         | 2448         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0071635167 |
# |    clip_fraction        | 0.0843       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.36        |
# |    explained_variance   | 0.05         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.69e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00893     |
# |    value_loss           | 4.55e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 554         |
# |    ep_rew_mean          | -2.74e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 40          |
# |    time_elapsed         | 2519        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.005623588 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.0597      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 4.33e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 556          |
# |    ep_rew_mean          | -2.73e+03    |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 41           |
# |    time_elapsed         | 2574         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0071187867 |
# |    clip_fraction        | 0.0807       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0.0591       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.41e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 4.91e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 555        |
# |    ep_rew_mean          | -2.72e+03  |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 42         |
# |    time_elapsed         | 2633       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01210531 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.34      |
# |    explained_variance   | 0.0686     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.2e+03    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0101    |
# |    value_loss           | 3.17e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 552         |
# |    ep_rew_mean          | -2.69e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 43          |
# |    time_elapsed         | 2697        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006953197 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.064       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 3.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | -2.7e+03    |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 44          |
# |    time_elapsed         | 2760        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010220833 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.0732      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 4.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | -2.69e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 45          |
# |    time_elapsed         | 2823        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.019869665 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.0766      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.4e+03     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 4.17e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | -2.68e+03  |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 46         |
# |    time_elapsed         | 2883       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01022585 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.0785     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.54e+03   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0038    |
# |    value_loss           | 3.95e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 553         |
# |    ep_rew_mean          | -2.7e+03    |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 47          |
# |    time_elapsed         | 2947        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011371372 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0751      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 3.81e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 542         |
# |    ep_rew_mean          | -2.63e+03   |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 48          |
# |    time_elapsed         | 3015        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009689454 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0794      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0057     |
# |    value_loss           | 4.01e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 548        |
# |    ep_rew_mean          | -2.66e+03  |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 49         |
# |    time_elapsed         | 3079       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00995942 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.19      |
# |    explained_variance   | 0.0837     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.38e+03   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00525   |
# |    value_loss           | 4.4e+03    |
# ----------------------------------------
# ✅ FINISHED A: Cooperative model saved to /content/drive/MyDrive/FirecastRL_Models/ppo_fire_squad_coop.zip

# %%
# --- CELL 5: TRAIN EXPERIMENT B (GREEDY) ---
# No imports needed, environment is already loaded

print("💰 STARTED: Experiment B (Competitive/Greedy)")

# 1. Setup (Create NEW environment instance to reset everything)
raw_env_comp = WildfireEnv(num_agents=3, render_mode=None)
safe_env_comp = SafeWildfireWrapper(raw_env_comp)
# KEY CHANGE: mode="competitive"
comp_env = MultiAgentRewardWrapper(safe_env_comp, mode="competitive")

# 2. Train
model_comp = PPO("MultiInputPolicy", comp_env, verbose=1)
model_comp.learn(total_timesteps=100_000)

# 3. Save to Google Drive
save_name = f"{drive_save_path}/ppo_fire_squad_greedy"
model_comp.save(save_name)
print(f"✅ FINISHED B: Greedy model saved to {save_name}.zip")
print("😴 Work complete. You can wake up now!")
# Out:
# 💰 STARTED: Experiment B (Competitive/Greedy)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 509      |
# |    ep_rew_mean     | -557     |
# | time/              |          |
# |    fps             | 33       |
# |    iterations      | 1        |
# |    time_elapsed    | 61       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 678         |
# |    ep_rew_mean          | -572        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 2           |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.026144082 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | -0.034      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 131         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 626         |
# |    ep_rew_mean          | -512        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 3           |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011491066 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | -8.39e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 279         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 657         |
# |    ep_rew_mean          | -488        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 4           |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016743861 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | -0.0686     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 87.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 643         |
# |    ep_rew_mean          | -470        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 5           |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012958385 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | -0.000401   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 79.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 647         |
# |    ep_rew_mean          | -427        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 6           |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020761956 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.00403     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 33.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 651         |
# |    ep_rew_mean          | -400        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 7           |
# |    time_elapsed         | 418         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014318604 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.00245     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 613         |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 8           |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019222489 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | -0.0279     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 25.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 601         |
# |    ep_rew_mean          | -318        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 9           |
# |    time_elapsed         | 544         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.016936094 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.000693    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 19          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | -297        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 10          |
# |    time_elapsed         | 602         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010853775 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.00267     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 15.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 608          |
# |    ep_rew_mean          | -272         |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 11           |
# |    time_elapsed         | 665          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0136543885 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.3         |
# |    explained_variance   | 0.0392       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.26         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0115      |
# |    value_loss           | 11.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 608         |
# |    ep_rew_mean          | -254        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 12          |
# |    time_elapsed         | 723         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011439415 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0103      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 9.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 603         |
# |    ep_rew_mean          | -233        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 13          |
# |    time_elapsed         | 785         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010033526 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.00664     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 5.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 607         |
# |    ep_rew_mean          | -219        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 14          |
# |    time_elapsed         | 844         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011141182 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | -0.0134     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.96        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 5.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 613         |
# |    ep_rew_mean          | -207        |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 15          |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006585165 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.00368     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.377       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00487    |
# |    value_loss           | 3.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 606         |
# |    ep_rew_mean          | -193        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 16          |
# |    time_elapsed         | 965         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010014589 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.0084      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.679       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00483    |
# |    value_loss           | 1.93        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 606       |
# |    ep_rew_mean          | -183      |
# | time/                   |           |
# |    fps                  | 34        |
# |    iterations           | 17        |
# |    time_elapsed         | 1023      |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0120621 |
# |    clip_fraction        | 0.175     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.11     |
# |    explained_variance   | 0.0674    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.746     |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -0.0103   |
# |    value_loss           | 1.7       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 601         |
# |    ep_rew_mean          | -172        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 18          |
# |    time_elapsed         | 1085        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008957991 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.54        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 0.984       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 594         |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 19          |
# |    time_elapsed         | 1149        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010544987 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.366       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00542    |
# |    value_loss           | 0.808       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 590         |
# |    ep_rew_mean          | -152        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 20          |
# |    time_elapsed         | 1212        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013058148 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.345       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 0.516       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 588         |
# |    ep_rew_mean          | -144        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 21          |
# |    time_elapsed         | 1275        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009960931 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00766    |
# |    value_loss           | 0.363       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 577         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 22          |
# |    time_elapsed         | 1337        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007859567 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00586    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00498    |
# |    value_loss           | 0.194       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 582        |
# |    ep_rew_mean          | -131       |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 23         |
# |    time_elapsed         | 1395       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01255179 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.05      |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0948     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00877   |
# |    value_loss           | 0.178      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 582         |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 24          |
# |    time_elapsed         | 1458        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012988014 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0651      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 579          |
# |    ep_rew_mean          | -119         |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 25           |
# |    time_elapsed         | 1521         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0080982465 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.03        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0504       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00452     |
# |    value_loss           | 0.0738       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 571         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 26          |
# |    time_elapsed         | 1588        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009037022 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0527      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00752    |
# |    value_loss           | 0.0363      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 570         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 27          |
# |    time_elapsed         | 1646        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010056433 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00922     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 0.047       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 570         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 28          |
# |    time_elapsed         | 1709        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011308249 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.0752      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00829     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 0.0582      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 576          |
# |    ep_rew_mean          | -88.5        |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 29           |
# |    time_elapsed         | 1768         |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0136582805 |
# |    clip_fraction        | 0.188        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.01        |
# |    explained_variance   | 0.00517      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0115       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00964     |
# |    value_loss           | 0.0624       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 572        |
# |    ep_rew_mean          | -70.9      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 30         |
# |    time_elapsed         | 1828       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.01595457 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.01      |
# |    explained_variance   | 0.0272     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0114     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00571   |
# |    value_loss           | 0.0237     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 573        |
# |    ep_rew_mean          | -59.2      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 31         |
# |    time_elapsed         | 1886       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.01005714 |
# |    clip_fraction        | 0.111      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.99      |
# |    explained_variance   | 0.141      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00283   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0111    |
# |    value_loss           | 0.0236     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 565          |
# |    ep_rew_mean          | -41.9        |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 32           |
# |    time_elapsed         | 1949         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0146212205 |
# |    clip_fraction        | 0.16         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.97        |
# |    explained_variance   | -0.0622      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000889    |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00986     |
# |    value_loss           | 0.0545       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 566          |
# |    ep_rew_mean          | -30.6        |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 33           |
# |    time_elapsed         | 2012         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0078109764 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.95        |
# |    explained_variance   | -0.0327      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00995     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00598     |
# |    value_loss           | 0.0204       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 34          |
# |    time_elapsed         | 2076        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010447752 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | -0.128      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00708     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 0.00224     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 562         |
# |    ep_rew_mean          | -15         |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 35          |
# |    time_elapsed         | 2135        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012623101 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | -0.0775     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00865     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 0.00135     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 571        |
# |    ep_rew_mean          | -12.5      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 36         |
# |    time_elapsed         | 2194       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01185197 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.98      |
# |    explained_variance   | -0.002     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00124    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00652   |
# |    value_loss           | 0.0176     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 568        |
# |    ep_rew_mean          | -8.72      |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 37         |
# |    time_elapsed         | 2257       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01664799 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.99      |
# |    explained_variance   | -0.0177    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0226    |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0067    |
# |    value_loss           | 0.0153     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 568         |
# |    ep_rew_mean          | -6.26       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 38          |
# |    time_elapsed         | 2315        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008879796 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 0.000713    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 567         |
# |    ep_rew_mean          | -4.46       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 39          |
# |    time_elapsed         | 2378        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.012625645 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0386     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 0.000276    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 566         |
# |    ep_rew_mean          | -3.54       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 40          |
# |    time_elapsed         | 2437        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018859804 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.00207     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00839    |
# |    value_loss           | 0.0174      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 573         |
# |    ep_rew_mean          | -2.84       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 41          |
# |    time_elapsed         | 2495        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009637092 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00171     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0081     |
# |    value_loss           | 0.000142    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 567         |
# |    ep_rew_mean          | -2.22       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 42          |
# |    time_elapsed         | 2553        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013974812 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0088      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 8.79e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 563         |
# |    ep_rew_mean          | -1.48       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 43          |
# |    time_elapsed         | 2616        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009919812 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.0895      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00907    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 5.54e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 573         |
# |    ep_rew_mean          | -1.24       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 44          |
# |    time_elapsed         | 2675        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007948079 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0242     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 4.48e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 573         |
# |    ep_rew_mean          | -0.98       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 45          |
# |    time_elapsed         | 2734        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008262323 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 2.57e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 578         |
# |    ep_rew_mean          | -0.82       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 46          |
# |    time_elapsed         | 2794        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009925116 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00977    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 1.62e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 578         |
# |    ep_rew_mean          | -0.72       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 47          |
# |    time_elapsed         | 2852        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010215623 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00775    |
# |    value_loss           | 1.16e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 585         |
# |    ep_rew_mean          | -0.66       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 48          |
# |    time_elapsed         | 2912        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011694351 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.00765     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0277     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 588         |
# |    ep_rew_mean          | -0.58       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 49          |
# |    time_elapsed         | 2976        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013300303 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | -0.359      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0227     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 0.000549    |
# -----------------------------------------
# ✅ FINISHED B: Greedy model saved to /content/drive/MyDrive/FirecastRL_Models/ppo_fire_squad_greedy.zip
# 😴 Work complete. You can wake up now!

# %%
# --- CELL 6: EVALUATION & DATA COLLECTION ---
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Settings
EVAL_EPISODES = 10  # Number of runs per agent to get statistically significant data

def collect_evaluation_data(model_path, agent_name):
    print(f"📊 Collecting data for: {agent_name}...")

    # Setup Eval Env (Just physics, no reward shaping needed for stats)
    raw_env = WildfireEnv(num_agents=3, render_mode=None)
    env = SafeWildfireWrapper(raw_env)

    try:
        model = PPO.load(model_path)
    except FileNotFoundError:
        print(f"❌ Model not found: {model_path}")
        return None, None

    # Store results
    episode_stats = []  # Final stats per episode (Burnt, Extinguished)
    fire_curves = []    # Time-series of fire size (Step, Active Fire Count)

    for ep in range(EVAL_EPISODES):
        obs, _ = env.reset()
        done = False
        step = 0

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, _, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            # Capture Time-Series Data
            fire_curves.append({
                "Agent": agent_name,
                "Episode": ep,
                "Step": step,
                "Active Fire": info['cells_burning']
            })
            step += 1

        # Capture Final Episode Data
        episode_stats.append({
            "Agent": agent_name,
            "Episode": ep,
            "Final Burnt Cells": info['cells_burnt'],
            "Total Quenched": obs['quenched_cells'][0] # Approximation
        })
        print(f"   Run {ep+1}/{EVAL_EPISODES}: Burnt = {info['cells_burnt']}")

    return pd.DataFrame(episode_stats), pd.DataFrame(fire_curves)

# --- RUN DATA COLLECTION ---
# Load paths from where we saved them in Drive
path_coop = f"{drive_save_path}/ppo_fire_squad_coop"
path_comp = f"{drive_save_path}/ppo_fire_squad_greedy"

# Collect
df_stats_coop, df_curves_coop = collect_evaluation_data(path_coop, "Cooperative")
df_stats_comp, df_curves_comp = collect_evaluation_data(path_comp, "Greedy")

# Merge Datasets
if df_stats_coop is not None and df_stats_comp is not None:
    full_stats = pd.concat([df_stats_coop, df_stats_comp])
    full_curves = pd.concat([df_curves_coop, df_curves_comp])
    print("\n✅ Data Collection Complete. Ready for plotting.")
else:
    print("\n❌ Error: Could not load one or both models.")
# Out:
# 📊 Collecting data for: Cooperative...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#    Run 1/10: Burnt = 1592
#    Run 2/10: Burnt = 1640
#    Run 3/10: Burnt = 1592
#    Run 4/10: Burnt = 1640
#    Run 5/10: Burnt = 1441
#    Run 6/10: Burnt = 1592
#    Run 7/10: Burnt = 1592
#    Run 8/10: Burnt = 1640
#    Run 9/10: Burnt = 1640
#    Run 10/10: Burnt = 1640
# 📊 Collecting data for: Greedy...
#    Run 1/10: Burnt = 1159
#    Run 2/10: Burnt = 1159
#    Run 3/10: Burnt = 1441
#    Run 4/10: Burnt = 1441
#    Run 5/10: Burnt = 301
#    Run 6/10: Burnt = 751
#    Run 7/10: Burnt = 301
#    Run 8/10: Burnt = 1441
#    Run 9/10: Burnt = 301
#    Run 10/10: Burnt = 1441
#
# ✅ Data Collection Complete. Ready for plotting.

# %%
# --- CELL 7: VISUALIZATION - FINAL DAMAGE (SAVED TO DRIVE) ---
if 'full_stats' in locals():
    plt.figure(figsize=(10, 6))
    sns.set_theme(style="whitegrid")

    # Create Box Plot
    ax = sns.boxplot(data=full_stats, x="Agent", y="Final Burnt Cells", palette="Set2")
    sns.stripplot(data=full_stats, x="Agent", y="Final Burnt Cells", color="black", alpha=0.3)

    plt.title("Comparison of Total Fire Damage (Lower is Better)", fontsize=16)
    plt.ylabel("Total Cells Burnt", fontsize=12)
    plt.xlabel("Strategy", fontsize=12)

    # Add mean labels
    means = full_stats.groupby("Agent")["Final Burnt Cells"].mean()
    for i, agent in enumerate(["Cooperative", "Greedy"]):
        if agent in means:
            plt.text(i, means[agent], f"Mean: {means[agent]:.1f}",
                     ha='center', va='bottom', fontweight='bold', color='darkred')

    # --- SAVE TO DRIVE ---
    plot_path = f"{drive_save_path}/plot_damage_comparison.png"
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    print(f"✅ Plot saved to: {plot_path}")

    plt.show()
# Out:
# /tmp/ipython-input-378925030.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=full_stats, x="Agent", y="Final Burnt Cells", palette="Set2")
# Analysis: The Box Plot shows the distribution of damage. If 'Cooperative' is lower, your hypothesis is correct.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# --- CELL 8: VISUALIZATION - FIRE SPEED (SAVED TO DRIVE) ---
if 'full_curves' in locals():
    plt.figure(figsize=(12, 7))

    # Create Line Plot
    sns.lineplot(data=full_curves, x="Step", y="Active Fire", hue="Agent", style="Agent", linewidth=2.5)

    plt.title("Fire Containment Trajectory (Speed of Suppression)", fontsize=16)
    plt.ylabel("Active Fire Size (Cells)", fontsize=12)
    plt.xlabel("Simulation Steps", fontsize=12)
    plt.legend(title="Strategy", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.xlim(0, 1000)

    # --- SAVE TO DRIVE ---
    plot_path = f"{drive_save_path}/plot_containment_speed.png"
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    print(f"✅ Plot saved to: {plot_path}")

    plt.show()
# Out:
# Analysis: This curve shows WHO IS FASTER. A steeper downward slope means the team reacts quicker.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# --- CELL 10: VISUALIZATION - SCATTER PLOT (SAVED TO DRIVE) ---
if 'full_stats' in locals() and 'full_curves' in locals():
    plt.figure(figsize=(10, 7))

    # 1. Calculate Duration for each episode
    # (We infer this from the max step count in the curves data)
    durations = full_curves.groupby(['Agent', 'Episode'])['Step'].max().reset_index()
    durations.rename(columns={'Step': 'Duration'}, inplace=True)

    # 2. Merge with the stats
    merged_data = pd.merge(full_stats, durations, on=['Agent', 'Episode'])

    # 3. Create Scatter Plot
    sns.scatterplot(
        data=merged_data,
        x="Duration",
        y="Final Burnt Cells",
        hue="Agent",
        style="Agent",
        s=100, # Dot size
        alpha=0.8,
        palette="deep"
    )

    plt.title("Efficiency Analysis: Damage vs. Duration", fontsize=16)
    plt.xlabel("Episode Duration (Steps)", fontsize=12)
    plt.ylabel("Total Burnt Cells", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)

    # --- SAVE ---
    plot_path = f"{drive_save_path}/plot_scatter_efficiency.png"
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    print(f"✅ Plot saved to: {plot_path}")

    plt.show()
# Out:
# ✅ Plot saved to: /content/drive/MyDrive/FirecastRL_Models/plot_scatter_efficiency.png
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# --- CELL 11: VISUALIZATION - RISK DENSITY (SAVED TO DRIVE) ---
if 'full_stats' in locals():
    plt.figure(figsize=(10, 6))

    # Kernel Density Estimate (KDE) Plot
    # "fill=True" makes the area under the curve solid
    sns.kdeplot(
        data=full_stats,
        x="Final Burnt Cells",
        hue="Agent",
        fill=True,
        alpha=0.3,
        linewidth=2.5,
        palette="rocket"
    )

    plt.title("Risk Profile: Probability of Damage Outcomes", fontsize=16)
    plt.xlabel("Total Burnt Cells", fontsize=12)
    plt.ylabel("Probability Density", fontsize=12)
    plt.grid(axis='x', linestyle='--', alpha=0.5)

    # --- SAVE ---
    plot_path = f"{drive_save_path}/plot_risk_density.png"
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    print(f"✅ Plot saved to: {plot_path}")

    plt.show()
# Out:
# ✅ Plot saved to: /content/drive/MyDrive/FirecastRL_Models/plot_risk_density.png
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# --- CELL 12: EXTENDED FINAL REPORT SUMMARY ---
if 'full_stats' in locals() and 'full_curves' in locals():
    print("="*60)
    print("🔥 FIRECAST RL - FINAL PROJECT REPORT 🔥")
    print("="*60)

    # 1. Calculate Duration (Speed) for each episode
    # (We extract this from the curves data like we did for the scatter plot)
    durations = full_curves.groupby(['Agent', 'Episode'])['Step'].max().reset_index()
    durations.rename(columns={'Step': 'Duration'}, inplace=True)

    # Merge duration into the main stats dataframe
    final_data = pd.merge(full_stats, durations, on=['Agent', 'Episode'])

    # 2. Group by Agent and calculate comprehensive stats
    summary = final_data.groupby("Agent").agg({
        "Final Burnt Cells": ["mean", "std", "min", "max"],
        "Total Quenched": ["mean"],
        "Duration": ["mean", "std"]  # NEW: Track speed!
    }).round(2)

    # Rename columns for clarity
    summary.columns = [
        "Avg Burnt", "Risk (Std)", "Best Case", "Worst Case",
        "Avg Quenched",
        "Avg Steps (Speed)", "Speed Var"
    ]

    print("\n📊 STATISTICAL PERFORMANCE:")
    print(summary)

    # 3. Calculate Improvement Percentages
    means = final_data.groupby("Agent")["Final Burnt Cells"].mean()
    speeds = final_data.groupby("Agent")["Duration"].mean()

    if "Cooperative" in means and "Greedy" in means:
        diff_burn = means["Greedy"] - means["Cooperative"]
        pct_burn = (diff_burn / means["Greedy"]) * 100

        diff_speed = speeds["Greedy"] - speeds["Cooperative"]

        print("\n🏆 FINAL CONCLUSION:")
        print(f"1. DAMAGE CONTROL:")
        if diff_burn > 0:
            print(f"   - The COOPERATIVE squad saved {diff_burn:.2f} more trees on average.")
            print(f"   - This is a {pct_burn:.1f}% improvement in forest protection.")
        else:
            print(f"   - The Greedy squad actually saved {abs(diff_burn):.2f} more trees.")

        print(f"\n2. EFFICIENCY:")
        if diff_speed > 0:
             print(f"   - The COOPERATIVE squad was faster by {diff_speed:.1f} steps.")
        else:
             print(f"   - The Greedy squad was faster by {abs(diff_speed):.1f} steps.")

    print("\n✅ Recommendation: Copy these numbers into your PDF report table.")
    print("="*60)
# Out:
# ============================================================
# 🔥 FIRECAST RL - FINAL PROJECT REPORT 🔥
# ============================================================
#
# 📊 STATISTICAL PERFORMANCE:
#              Avg Burnt  Risk (Std)  Best Case  Worst Case  Avg Quenched  \
# Agent
# Cooperative     1600.9       61.04       1441        1640           0.0
# Greedy           973.6      510.92        301        1441           0.0
#
#              Avg Steps (Speed)  Speed Var
# Agent
# Cooperative              728.1      65.37
# Greedy                   432.1     157.97
#
# 🏆 FINAL CONCLUSION:
# 1. DAMAGE CONTROL:
#    - The Greedy squad actually saved 627.30 more trees.
#
# 2. EFFICIENCY:
#    - The Greedy squad was faster by 296.0 steps.
#
# ✅ Recommendation: Copy these numbers into your PDF report table.
# ============================================================
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
