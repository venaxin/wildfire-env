# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from firecastrl_env.envs.wildfire_env import WildfireEnv
from firecastrl_env.envs.environment import helper 

# --- 1. Define Wrapper ---
class SafeWildfireWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
    def observation(self, obs):
        if 'cells' in obs:
            obs['cells'] = np.nan_to_num(obs['cells'], posinf=-1.0)
        return obs

class MultiAgentRewardWrapper(gym.Wrapper):
    def __init__(self, env, mode="cooperative"):
        super().__init__(env)
        self.mode = mode.lower()
        
    def step(self, action):
        obs, _, terminated, truncated, info = self.env.step(action)
        if self.mode == "cooperative":
            new_reward = self._calculate_cooperative(info, obs)
        else:
            new_reward = self._calculate_competitive(info)
        return obs, float(new_reward), terminated, truncated, info

    def _calculate_cooperative(self, info, obs):
        curr_burning = info['cells_burning']
        total_extinguished = obs['quenched_cells'][0]
        reward = 10.0 * total_extinguished
        reward -= 0.1 * curr_burning
        reward -= self._calculate_wasted_water_penalty()
        return np.clip(reward, -50.0, 50.0)

    def _calculate_competitive(self, info):
        # This function is here but won't be used in this specific run
        wasted_penalty = self._calculate_wasted_water_penalty()
        total_extinguished = self.env.unwrapped.state['quenched_cells'][0]
        reward = 10.0 * total_extinguished
        reward -= wasted_penalty
        return np.clip(reward, -50.0, 50.0)

    def _calculate_wasted_water_penalty(self):
        penalty = 0.0
        base_env = self.env.unwrapped
        for i in range(base_env.num_agents):
            last_act = base_env.state['last_action'][i]
            hx, hy = base_env.state['helicopter_coord'][i]
            if last_act == 4:
                cell_idx = helper.get_grid_index_for_location(hx, hy, base_env.gridWidth)
                cell = base_env.cells[cell_idx]
                if cell.fireState != 1: 
                    penalty += 2.0
        return penalty

# --- 2. Train COOPERATIVE ---
print("🔥 Starting COOPERATIVE Training...")
raw_env = WildfireEnv(num_agents=3)
safe_env = SafeWildfireWrapper(raw_env)
coop_env = MultiAgentRewardWrapper(safe_env, mode="cooperative")

model_coop = PPO("MultiInputPolicy", coop_env, verbose=1)
model_coop.learn(total_timesteps=100_000)
model_coop.save("ppo_fire_squad_coop")
print("✅ Cooperative Model Saved!")
# Out:
# 🔥 Starting COOPERATIVE Training...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 875      |
# |    ep_rew_mean     | -4.2e+03 |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 1        |
# |    time_elapsed    | 102      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 725         |
# |    ep_rew_mean          | -3.54e+03   |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 2           |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008696465 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.82       |
# |    explained_variance   | -0.00943    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.14e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00921    |
# |    value_loss           | 7.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 739         |
# |    ep_rew_mean          | -3.78e+03   |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 3           |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009333249 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.81       |
# |    explained_variance   | 0.000375    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 8.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 655         |
# |    ep_rew_mean          | -3.43e+03   |
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 4           |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010046449 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.8        |
# |    explained_variance   | 0.000176    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.85e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 8.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 661         |
# |    ep_rew_mean          | -3.5e+03    |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 5           |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009148423 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.78       |
# |    explained_variance   | 8.42e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 9.66e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 674        |
# |    ep_rew_mean          | -3.57e+03  |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 6          |
# |    time_elapsed         | 797        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00945982 |
# |    clip_fraction        | 0.0998     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.79      |
# |    explained_variance   | 2.54e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.91e+03   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0135    |
# |    value_loss           | 8.78e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 655         |
# |    ep_rew_mean          | -3.52e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 7           |
# |    time_elapsed         | 941         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010706171 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.77       |
# |    explained_variance   | 2.52e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.61e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 7.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 657         |
# |    ep_rew_mean          | -3.52e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 8           |
# |    time_elapsed         | 1065        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011031975 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 1.97e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.54e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | -3.49e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 9           |
# |    time_elapsed         | 1183        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011951875 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.74       |
# |    explained_variance   | 1.99e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.17e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 7.55e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 632        |
# |    ep_rew_mean          | -3.4e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 10         |
# |    time_elapsed         | 1301       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00845919 |
# |    clip_fraction        | 0.0816     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.74      |
# |    explained_variance   | 1.19e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.66e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 8.7e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 641         |
# |    ep_rew_mean          | -3.43e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 11          |
# |    time_elapsed         | 1412        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009516288 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 8.4e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 7.42e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 644         |
# |    ep_rew_mean          | -3.41e+03   |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 12          |
# |    time_elapsed         | 1504        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010449588 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.71       |
# |    explained_variance   | 6.5e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8e+03     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00857    |
# |    value_loss           | 5.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 643         |
# |    ep_rew_mean          | -3.4e+03    |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 13          |
# |    time_elapsed         | 1610        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009924049 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.72       |
# |    explained_variance   | 4.83e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 5.78e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 635         |
# |    ep_rew_mean          | -3.38e+03   |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 14          |
# |    time_elapsed         | 1731        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009961511 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 4.89e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 7.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 639         |
# |    ep_rew_mean          | -3.39e+03   |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 15          |
# |    time_elapsed         | 1840        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009231395 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 4.65e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 7.44e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | -3.4e+03    |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 16          |
# |    time_elapsed         | 1941        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010168364 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.69       |
# |    explained_variance   | 3.58e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00887    |
# |    value_loss           | 6.68e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 646          |
# |    ep_rew_mean          | -3.39e+03    |
# | time/                   |              |
# |    fps                  | 16           |
# |    iterations           | 17           |
# |    time_elapsed         | 2065         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0138489595 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.66        |
# |    explained_variance   | 1.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.91e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0132      |
# |    value_loss           | 5.42e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 646         |
# |    ep_rew_mean          | -3.39e+03   |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 18          |
# |    time_elapsed         | 2235        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007540763 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 2.68e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 6.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 633         |
# |    ep_rew_mean          | -3.31e+03   |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 19          |
# |    time_elapsed         | 2401        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.008227111 |
# |    clip_fraction        | 0.0899      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.68       |
# |    explained_variance   | 2.68e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00772    |
# |    value_loss           | 5.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 635         |
# |    ep_rew_mean          | -3.29e+03   |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 20          |
# |    time_elapsed         | 2557        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009323559 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.73       |
# |    explained_variance   | 1.61e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.69e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00955    |
# |    value_loss           | 5.98e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 638        |
# |    ep_rew_mean          | -3.3e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 21         |
# |    time_elapsed         | 2695       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01383809 |
# |    clip_fraction        | 0.233      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.68      |
# |    explained_variance   | 1.85e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.37e+03   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00252   |
# |    value_loss           | 5.15e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 637         |
# |    ep_rew_mean          | -3.28e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 22          |
# |    time_elapsed         | 2845        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011120263 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.64       |
# |    explained_variance   | 2.03e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0093     |
# |    value_loss           | 4.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 644         |
# |    ep_rew_mean          | -3.29e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 23          |
# |    time_elapsed         | 2999        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009918079 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.64       |
# |    explained_variance   | 1.49e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 4.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | -3.3e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 24          |
# |    time_elapsed         | 3124        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010652947 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 1.49e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 4.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 639         |
# |    ep_rew_mean          | -3.24e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 25          |
# |    time_elapsed         | 3275        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008704723 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 1.67e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6e+03     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00836    |
# |    value_loss           | 5.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 634         |
# |    ep_rew_mean          | -3.2e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 26          |
# |    time_elapsed         | 3415        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009774161 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.61       |
# |    explained_variance   | 1.49e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00795    |
# |    value_loss           | 3.9e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 636          |
# |    ep_rew_mean          | -3.19e+03    |
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 27           |
# |    time_elapsed         | 3555         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0121215265 |
# |    clip_fraction        | 0.164        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.58        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.35e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.00157      |
# |    value_loss           | 4.25e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 639         |
# |    ep_rew_mean          | -3.19e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 28          |
# |    time_elapsed         | 3688        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012815111 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 1.43e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 3.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 643         |
# |    ep_rew_mean          | -3.2e+03    |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 29          |
# |    time_elapsed         | 3830        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012667097 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 1.31e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 3.96e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 640         |
# |    ep_rew_mean          | -3.18e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 30          |
# |    time_elapsed         | 3969        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013779117 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 1.31e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1e+03     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 4.2e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 631         |
# |    ep_rew_mean          | -3.14e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 31          |
# |    time_elapsed         | 4113        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010520024 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 8.34e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00789    |
# |    value_loss           | 4.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 631         |
# |    ep_rew_mean          | -3.13e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 32          |
# |    time_elapsed         | 4241        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010497864 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 1.79e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.41e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 5.46e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 629        |
# |    ep_rew_mean          | -3.1e+03   |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 33         |
# |    time_elapsed         | 4394       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01333759 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.4       |
# |    explained_variance   | 0.00434    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.77e+03   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0106    |
# |    value_loss           | 3.97e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 618         |
# |    ep_rew_mean          | -3.02e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 34          |
# |    time_elapsed         | 4551        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009539689 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.00119     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00773    |
# |    value_loss           | 3.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 610         |
# |    ep_rew_mean          | -2.96e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 35          |
# |    time_elapsed         | 4692        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.010575382 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.0117      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 4.11e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 611         |
# |    ep_rew_mean          | -2.95e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 36          |
# |    time_elapsed         | 4835        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013198832 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.022       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 4.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 618         |
# |    ep_rew_mean          | -2.96e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 37          |
# |    time_elapsed         | 4994        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.012471326 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.36       |
# |    explained_variance   | 0.0285      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 4.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | -2.94e+03   |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 38          |
# |    time_elapsed         | 5170        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008212577 |
# |    clip_fraction        | 0.0717      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.0249      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 3.91e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | -2.93e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 39          |
# |    time_elapsed         | 5331        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011219964 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | 0.0313      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 4.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | -2.95e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 40          |
# |    time_elapsed         | 5476        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010462704 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | 0.0456      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.61e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 4.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 623         |
# |    ep_rew_mean          | -2.94e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 41          |
# |    time_elapsed         | 5610        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.020080667 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.031       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 3.61e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 615          |
# |    ep_rew_mean          | -2.91e+03    |
# | time/                   |              |
# |    fps                  | 14           |
# |    iterations           | 42           |
# |    time_elapsed         | 5763         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0118888505 |
# |    clip_fraction        | 0.144        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.0267       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.15e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0125      |
# |    value_loss           | 3.88e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 620        |
# |    ep_rew_mean          | -2.92e+03  |
# | time/                   |            |
# |    fps                  | 14         |
# |    iterations           | 43         |
# |    time_elapsed         | 5939       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.00929448 |
# |    clip_fraction        | 0.0973     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.28      |
# |    explained_variance   | 0.0499     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.91e+03   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.00781   |
# |    value_loss           | 4.76e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 623         |
# |    ep_rew_mean          | -2.91e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 44          |
# |    time_elapsed         | 6081        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007007376 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.0458      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.73e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00979    |
# |    value_loss           | 4.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 615         |
# |    ep_rew_mean          | -2.86e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 45          |
# |    time_elapsed         | 6292        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.028323814 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.0673      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00932     |
# |    value_loss           | 3.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 604         |
# |    ep_rew_mean          | -2.82e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 46          |
# |    time_elapsed         | 6456        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.013745012 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.0772      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00383    |
# |    value_loss           | 4.78e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 608         |
# |    ep_rew_mean          | -2.83e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 47          |
# |    time_elapsed         | 6619        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.016328987 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.0762      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+03     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 5.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 611         |
# |    ep_rew_mean          | -2.82e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 48          |
# |    time_elapsed         | 6780        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009945295 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.0595      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00824    |
# |    value_loss           | 3.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 618         |
# |    ep_rew_mean          | -2.86e+03   |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 49          |
# |    time_elapsed         | 6912        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007267699 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00771    |
# |    value_loss           | 4.11e+03    |
# -----------------------------------------
# ✅ Cooperative Model Saved!
